# %% [markdown]
# # Extracción de texto de Diferentes Fuentes de datos

# %% [markdown]
# Realizar una prueba con ChatGTP y Dalle
# https://chat.openai.com/chat
#
# https://labs.openai.com/

# %% [markdown]
# **Temas:**
# 1.	Recolectando datos.
# 2.	Recopilación de datos de archivos PDF (documento Word)
# 3.	Recopilación de datos de archivos de Word.
# 4.	Recopilar datos de JSON
# 5.	Recopilar datos de HTML
# 6.	Analizar texto con expresiones regulares
# 7.	Manejo de cadenas.
# 8.	Extracción de texto de la web (beautifulsoup)

# %% [markdown]
# **1. Recolectando datos**
#
# Existen Diferentes fuentes de datos de donde se pueden extraer datasets:
#
# - Plataforma Nacional de Datos Abiertos: http://datosabiertos.gob.pe/
#
# - https://www.troomes.com/viewforum.php?f=39
#
# - Kaggle: https://www.kaggle.com/competitions
#
# - https://u.cs.biu.ac.il/~koppel/BlogCorpus.htm
#
# - https://www.dt.fee.unicamp.br/~tiago/smsspamcollection/
#
# - https://cseweb.ucsd.edu//~jmcauley/datasets.html
#
# - http://help.sentiment140.com/for-students/
#
# - https://metatext.io/datasets/cc100-spanish
#
#
# Source: https://odsc.medium.com/20-open-datasets-for-natural-language-processing-538fbfaf8e38
#
# Source: https://metatext.io/datasets-list/spanish-language

# %% [markdown]
# 1.1 Uso de urllib para leer datos de internet
#
# https://docs.python.org/es/3/howto/urllib2.html

# %% [markdown]
# Ejemplo 1:

# %%
from urllib.request import urlopen
textPage = urlopen(
"http://www.pythonscraping.com/pages/warandpeace/chapter1.txt")
print(textPage.read())
# Out:
# b'CHAPTER I\n\n"Well, Prince, so Genoa and Lucca are now just family estates of theBuonapartes. But I warn you, if you don\'t tell me that this means war,if you still try to defend the infamies and horrors perpetrated bythat Antichrist- I really believe he is Antichrist- I will havenothing more to do with you and you are no longer my friend, no longermy \'faithful slave,\' as you call yourself! But how do you do? I seeI have frightened you- sit down and tell me all the news."\n\nIt was in July, 1805, and the speaker was the well-known AnnaPavlovna Scherer, maid of honor and favorite of the Empress MaryaFedorovna. With these words she greeted Prince Vasili Kuragin, a manof high rank and importance, who was the first to arrive at herreception. Anna Pavlovna had had a cough for some days. She was, asshe said, suffering from la grippe; grippe being then a new word inSt. Petersburg, used only by the elite.\n\nAll her invitations without exception, written in French, anddelivered by a scarlet-liveried footman that morning, ran as follows:\n\n"If you have nothing better to do, Count [or Prince], and if theprospect of spending an evening with a poor invalid is not tooterrible, I shall be very charmed to see you tonight between 7 and 10-Annette Scherer."\n\n"Heavens! what a virulent attack!" replied the prince, not in theleast disconcerted by this reception. He had just entered, wearingan embroidered court uniform, knee breeches, and shoes, and hadstars on his breast and a serene expression on his flat face. He spokein that refined French in which our grandfathers not only spoke butthought, and with the gentle, patronizing intonation natural to aman of importance who had grown old in society and at court. He wentup to Anna Pavlovna, kissed her hand, presenting to her his bald,scented, and shining head, and complacently seated himself on thesofa.\n\n"First of all, dear friend, tell me how you are. Set your friend\'smind at rest," said he without altering his tone, beneath thepoliteness and affected sympathy of which indifference and evenirony could be discerned.\n\n"Can one be well while suffering morally? Can one be calm in timeslike these if one has any feeling?" said Anna Pavlovna. "You arestaying the whole evening, I hope?"\n\n"And the fete at the English ambassador\'s? Today is Wednesday. Imust put in an appearance there," said the prince. "My daughter iscoming for me to take me there."\n\n"I thought today\'s fete had been canceled. I confess all thesefestivities and fireworks are becoming wearisome."\n\n"If they had known that you wished it, the entertainment wouldhave been put off," said the prince, who, like a wound-up clock, byforce of habit said things he did not even wish to be believed.\n\n"Don\'t tease! Well, and what has been decided about Novosiltsev\'sdispatch? You know everything."\n\n"What can one say about it?" replied the prince in a cold,listless tone. "What has been decided? They have decided thatBuonaparte has burnt his boats, and I believe that we are ready toburn ours."\n\nPrince Vasili always spoke languidly, like an actor repeating astale part. Anna Pavlovna Scherer on the contrary, despite her fortyyears, overflowed with animation and impulsiveness. To be anenthusiast had become her social vocation and, sometimes even when shedid not feel like it, she became enthusiastic in order not todisappoint the expectations of those who knew her. The subdued smilewhich, though it did not suit her faded features, always playedround her lips expressed, as in a spoiled child, a continualconsciousness of her charming defect, which she neither wished, norcould, nor considered it necessary, to correct.\n\nIn the midst of a conversation on political matters Anna Pavlovnaburst out:\n\n"Oh, don\'t speak to me of Austria. Perhaps I don\'t understandthings, but Austria never has wished, and does not wish, for war.She is betraying us! Russia alone must save Europe. Our gracioussovereign recognizes his high vocation and will be true ...

# %% [markdown]
# Ejemplo 2: Extraer contenido

# %%
import urllib.parse
import urllib.request

url = 'http://pythonprogramming.net/'
values = {'q' : 'basics',
          'submit' : 'Search'}
hdr = {'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
       'Accept-Language':'en-US,en;q=0.5',
       'Connection': 'keep-alive',
       'User-Agent':	'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/109.0'}

data = urllib.parse.urlencode(values)
data = data.encode('ascii') # data should be bytes
req = urllib.request.Request(url, data,headers=hdr)
print(data)
with urllib.request.urlopen(req) as response:
   the_page = response.read()
   text = the_page.decode('utf-8')

print(text)
# Out:
# b'q=basics&submit=Search'
# <html>
# 	<head>
#
# 		<!--
# 		palette:
# 		dark blue: #003F72
# 		yellow: #FFD166
# 		salmon: #EF476F
# 		offwhite: #e7d7d7
# 		Light Blue: #118AB2
# 		Light green: #7DDF64
# 		-->
#
# 		<meta name="viewport" content = "width=device-width, initial-scale=1.0">
# 		<title>Python Programming Tutorials</title>
#
# 		<meta name="description" content="Python Programming tutorials from beginner to advanced on a massive variety of topics. All video and text tutorials are free.">
#
# 		<link rel="shortcut icon" href="/static/favicon.ico">
# 		<link rel="stylesheet" href="/static/css/materialize.min.css">
#         <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
#         <meta name="google-site-verification" content="3fLok05gk5gGtWd_VSXbSSSH27F2kr1QqcxYz9vYq2k" />
#         <link rel="stylesheet" type="text/css" href="/static/css/bootstrap.css">
#
#
# 		  <!-- Compiled and minified CSS -->
#
# 		<!-- Compiled and minified JavaScript -->
#
# 		<script src="https://code.jquery.com/jquery-2.1.4.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.3/js/materialize.min.js"></script>
#
#
#
#         <style>
# 		@media (min-width:992px) {
# 		#aside {
# 			width:250px;
# 		}
# 		pre { tab-size: 4;}
# 		.btn {background-color:#FFD166;
# 			  color:#000;
# 		      height:auto;
# 			  font-color:#000;
# 			  }
# 		.btn:hover {background-color:#FFD166;
# 					}
#
#
# 		</style>
#
# 		<!-- Google Tracking -->
# 		<script>
# 			  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 			  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 			  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 			  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#               ga('config', 'UA-51891827-1', {'anonymize_ip': true});﻿
# 			  ga('create', 'UA-51891827-1', 'auto');
# 			  ga('send', 'pageview');
#
# 		</script>
#
#
#
#
#
#
#
# 	</head>
#
# 	<body>
#
# 		<div class="navbar-fixed">
# 			<nav style="background-color:#003F72">
# 				<div class="nav-wrapper container">
# 					<a href="/" class="brand-logo"><img class="img-responsive" style="width:50px; height;50px; margin-top:5px" src="/static/images/mainlogowhitethick.jpg"></a>
# 					<a href="#" data-activates="navsidebar" class="button-collapse"><i class="mdi-navigation-menu"></i></a>
# 					<ul class="right hide-on-med-and-down">
# 					<li><i class="material-icons">search</i></li>
# 					<li>
# 						<form method='get' id='searchform' style='height:50px; padding-top:10px' action='/search/?l=hi'>
# 							<input name='q' id="search" type="search" placeholder="search"  style='font-size:16px'>
# 						</form>
# 					</li>
#
# 			<li><a href="/">Home</a></li>
# 			<li><a class="tooltipped" data-position="bottom" data-delay="50" data-tooltip="sudo apt-get upgrade" href="/+=1/">+=1</a></li>
# 			<!--<li><a href="/store/python-hoodie/">Store</a></li>-->
# 			<li><a href="/support/">Support the Content</a></li>
#
# 			<li><a href="https://goo.gl/7zgAVQ" target='blank'><!--<i class="material-icons">question_answer</i>-->Community</a></li>
# 				<li><a href="/login/">Log in</a></li>
#                 <li><a href="/register/">Sign up</a></li>
#
#
# 					</ul>
# 					<ul class="side-nav" id="navsidebar">
# 					<li>
# 						<form method='get' id='searchform' style='height:50px; padding-top:10px' action='/search/?l=hi'>
# 							<input name='q' id="search" type="search" placeholder="search"  style='font-size:16px'>
# 						</form>
# 					</li>
#
# 			<li><a href="/">Home</a></li>
# 			<li><a class="tooltipped" data-position="bottom" data-delay="50" data-tooltip="sudo apt-get upgrade" href="/+=1/">+=1</a></li>
# 			<!--<li><a href="/store/python-hoodie/">Store</a></li>-->
# 			<li><a href="/support/">Support the Content</a></li>
#
# 			<li><a href="https://goo.gl/7zgAVQ" target='blank'><!--<i class="material-icons">question_answer</i>-->Community</a></li>
# 				<li><a href="/login/">Log in</a></li>
#                 <li><a href="/register/">Sign up</a></li>
#
#
# 					</ul>
# 				</div>
# 			</nav>
# 		</div>
#
#
#
# 		<!-- main content -->
# 		<div class="container" style="max-width:1500px; min-height:100%">
# 			<!--Notification:-->
#             <!--<p style="font-size:80%">TensorFlow.js Livestream:  <a href="https://www.youtube.com/watch?v=NjSlj95lliM" target="blank"><strong>Deep Learning in the browser</strong></a></p>-->
#             <!--End Notification:-->
#
#
#
#
#
#
#
#
#
#
# 	<div class="row">
# 	<!-- size 4 on a large screen, 12 on a small, 6 on a med -->
#         <div class="col l4 s12 m6">
#           <a href="/machine-learning-tutorials/" class="waves-effect waves-light" style="color:#000">
#             <div class="card-panel hoverable" style="height:360px; background-color:#FFFFFF;">
#               <div class="card-image">
#                 <img class="responsive-img" src="/static/images/categories/machine-learning-playlist.png" style="width:250px">
#                 <br><span class="card-title"><strong>Machine Learning</strong></span>
#               </div>
#               <div class="card-content">
#                 <p>Employ both supervised and unsupervised machine learning, to make predictions or to understand data.</p>
#               </div>
#               <div class="card-action right-align">
#                 <a href="/machine-learning-tutorials/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">View</a>
#               </div>
#             </div>
#           </a>
#         </div>
#
#
# 		<div class="col l4 s12 m6">
# 			<a href="/data-analysis-tutorials/" class="waves-effect waves-light" style="color:#000">
# 			<div class="card-panel hoverable" style="height:360px; background-color:#FFFFFF;">
# 				<div class="card-image">
# 				  <img class="responsive-img" src="/static/images/categories/3D-Matplotlib.png" style="width:250px">
# 				  <br><span class="card-title"><strong>Data Analysis</strong></span>
# 				</div>
# 				<div class="card-content">
# 				  <p>Learn how to use Python with Pandas, Matplotlib, and other modules to gather insights from and about your data.</p>
# 				</div>
# 				<div class="card-action right-align">
# 				  <a href="/data-analysis-tutorials/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">View</a>
# 				</div>
#             </div>
#             </a>
# 		</div>
#
#
#
# 		<div class="col l4 s12 m6">
#
# 			<div class="card-panel hoverable" style="height:360px; background-color:#FFFFFF;">
# 			<a href="/quantum-computer-programming-tutorial/" class="waves-effect waves-light" style="color:#000">
# 				<div class="card-image">
# 				  <img class="responsive-img" src="/static/images/categories/quantum-programming.png" style="width:250px">
# 				  <br><span class="card-title"><strong>Quantum Computer Programming</strong></span>
# 				</div>
# 				<div class="card-content">
# 				  <p>Learn the basics and concepts of working with quantum computers and qubits through practical applications and the Qiskit package.</p>
# 				</div>
# 				<div class="card-action right-align">
# 				  <a href="/quantum-computer-programming-tutorial/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">Start</a>
# 				</div>
# 				</a>
#             </div>
#
# 		</div>
# 	</div>
#
#
#
#
#
#
#
#
# 	<div class="row">
#
# 		<div class="col l3 s12 m6">
# 			<a href="/game-development-tutorials/" class="waves-effect waves-light" style="color:#000">
# 			<div class="card-panel hoverable" style="height:360px; background-color:#FFFFFF;">
# 				<div class="card-image">
# 				  <img class="responsive-img" src="/static/images/categories/pygame-tutorials.png" style="width:250px">
# 				  <br><span class="card-title"><strong>Game Development</strong></span>
# 				</div>
# 				<div class="card-content">
# 				  <p>Create your own games with Python's PyGame library, or check out the multi-platform Kivy.</p>
# 				</div>
# 				<div class="card-action right-align">
# 				  <a href="/game-development-tutorials/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">View</a>
# 				</div>
#             </div>
#             </a>
# 		</div>
#
#
#
# 		<div class="col l3 s12 m6">
# 			<a href="/python-fundamental-tutorials/" class="waves-effect waves-light" style="color:#000">
# 			<div class="card-panel hoverable" style="height:360px; background-color:#FFFFFF;">
# 				<div class="card-image">
# 				  <img class="responsive-img" src="/static/images/categories/python-3-basics.png" style="width:250px">
# 				  <br><span class="card-title"><strong>Python Fundamentals</strong></span>
# 				</div>
# 				<div class="card-content">
# 				  <p>Learn the basic and intermediate Python fundamentals.</p>
# 				</div>
# 				<div class="card-action right-align">
# 				  <a href="/python-fundamental-tutorials/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">View</a>
# 				</div>
#             </div>
#             </a>
# 		</div>
#
#
#
#
# 		<!--<div class="col l4 s12 m6">
#
# 			<div class="card-panel hoverable" style="height:360px; background-color:#FFFFFF;">
# 			<a href="/introduction-to-python-programming/" class="waves-effect waves-light" style="color:#000">
# 				<div class="card-image">
# 				  <img class="responsive-img" src="/static/images/categories/python-3-basics.png" style="width:250px">
# 				  <br><span class="card-title"><strong>Basics</strong></span>
# 				</div>
# 				<div class="card-content">
# 				  <p>Just getting started?</p>
# 				  <p>Not a problem, learn the basics of programming with Python 3 here!</p>
# 				</div>
# 				<div class="card-action right-align">
# 				  <a href="/introduction-to-python-programming/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">Start</a>
# 				</div>
# 				</a>
#             </div>
#
#
# 		</div>-->
#
#         <div class="col l3 s12 m6">
#             <a href="/web-development-tutorials/" class="waves-effect waves-light" style="color:#000">
#             <div class="card-panel hoverable" style="height:360px; background-color:#FFFFFF;">
#                 <div class="card-image">
#                   <img class="responsive-img" src="/static/images/categories/webdev.png" style="width:250px">
#                   <br><span class="card-title"><strong>Web Development</strong></span>
#                 </div>
#                 <div class="card-content">
#                   <p>How to develop websites with either the Flask or Django frameworks for Python.</p>
#                 </div>
#                 <div class="card-action right-align">
#                   <a href="/web-development-tutorials/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">View</a>
#                 </div>
#             </div>
#             </a>
#         </div>
#
# 		<div class="col l3 s12 m6">
# 			<a href="/bot-tutorials/" class="waves-effect waves-light" style="color:#000">
# 			<div class="card-panel hoverable" style="height:360px; background-color:#FFFFFF;">
# 				<div class="card-image">
# 				  <img class="responsive-img" src="/static/images/categories/bots.png" style="width:250px">
# 				  <br><span class="card-title"><strong>Bots &amp; AI</strong></span>
# 				</div>
# 				<div class="card-content">
# 				  <p>Creating various software bots, like bots in games, in chats, and to interact with the web. Not to be confused with robotics!</p>
# 				</div>
# 				<div class="card-action right-align">
# 				  <a href="/bot-tutorials/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">View</a>
# 				</div>
#             </div>
#             </a>
# 		</div>
# 	</div>
#
#
#
#
#
#
#
#
#     <div class="row">
#
#         <div class="col l4 s12 m6">
#             <a href="/robotics-tutorials/" class="waves-effect waves-light" style="color:#000">
#             <div class="card-panel hoverable" style="height:360px; background-color:#FFFFFF;">
#                 <div class="card-image">
#                   <img class="responsive-img" src="/static/images/categories/robotics_with_raspberry_pi_gopigo.jpg" style="width:250px">
#                   <br><span class="card-title"><strong>Robotics</strong></span>
#                 </div>
#                 <div class="card-content">
#                   <p>Control hardware with Python programming and the Raspberry Pi.</p>
#                 </div>
#                 <div class="card-action right-align">
#                   <a href="/robotics-tutorials/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">View</a>
#                 </div>
#             </div>
#             </a>
#         </div>
#
#         <div class="col l4 s12 m6">
#
#             <a href="/gui-development-tutorials/" class="waves-effect waves-light" style="color:#000">
#             <div class="card-panel hoverable" style="height:360px; background-color:#FFFFFF;">
#                 <div class="card-image">
#                   <img class="responsive-img" src="/static/images/categories/tkinter-gui-tutorial-with-python-3.png" style="width:250px">
#                   <br><span class="card-title"><strong>GUIs</strong></span>
#                 </div>
#                 <div class="card-content">
#                   <p>Create software with a user interface using Tkinter, PyQt, or Kivy.</p>
#                 </div>
#                 <div class="card-action right-align">
#                   <a href="/gui-development-tutorials/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">View</a>
#                 </div>
#             </div>
#             </a>
#
#         </div>
#
#
#
#         <div class="col l4 s12 m6">
#     	  <div class="card">
#     	    <!--<div class="card-content">
#     	      <p>Curious about more than just Python? While not covered in nearly as much depth, here are some tutorials in other languages:</p>
#     	    </div>-->
#
#     	    <div class="card-tabs">
#     	      <ul class="tabs tabs-fixed-width">
#     	        <li class="tab"><a class="active" href="#golang">Golang</a></li>
#     	        <!--<li class="tab"><a href="#cpp">C++</a></li>
#     	        <li class="tab"><a href="#julia">Julia</a></li>-->
#     	      </ul>
#     	    </div>
#
#     	    <div class="card-content grey lighten-4">
#     	      <div id="golang">
#     	        <p>Go is a programming language aimed at being simple, easy to work with, and capable of high performance.</p><br>
#     	        <a href="/go/">
#     	          <img class="responsive-img" src="/static/images/categories/golang-tutorials.png" style="width:150px;">
#     	        </a>
#
#     	        <div class="card-action left-align">
#     	          <a href="/go/" class="waves-effect waves-light btn" style="color:#000000; background-color:#FFD166">View Tutorial</a>
#     	        </div>
#     	      </div>
#
#     	      <!--<div id="gpp">C++ content</div>
#     	      <div id="julia">Julia content</div>-->
#
#     	    </div>
#     	  </div>
#         </div>
#
#
#     </div>
#
#
#
# 			</div>
# 		</div>
#
# 		<!--login modal-->
#
#
# 		<!--Register modal-->
#
#
#
# 		<script>
# 			$(document).ready(function(){
# 				$(".button-collapse").sideNav();
# 				$('.modal-trigger').leanModal();
# 				$('.collapsible').collapsible({
# 				  accordion : false // A setting that changes the collapsible behavior to expandable instead of the default accordion style
# 				});
# 				$('#aside').pushpin({ top:110, bottom:500 });
# 		  });
# 		</script>
# 		<script>
# 		  $(document).ready(function(){
# 			$('.collapsible').collapsible({
# 			  accordion : false // A setting that changes the collapsible behavior to expandable instead of the default accordion style
# 			});
# 			$('select').material_select();
# 		  });
# 	  </script>
# 	  <script>
# 		function goBack() {
# 			window.history.back()
# 		}
# 	</script>
# 		<script type="text/javascript" src="/static/js/run_prettify.js"></script>
#
# 	</body>
#
# <footer class="page-footer">
#           <div class="container">
#             <div class="row">
#               <div class="col l6 s12">
#                 <h5 class="white-text">You've reached the end!</h5>
#
#                 <p class="grey-text text-lighten-4">Contact: Harrison@pythonprogramming.net.</p>
#                 <ul>
#                   <li><a class="grey-text text-lighten-3" href="/support-donate/">Support this Website!</a></li>
#                   <li><a class="grey-text text-lighten-3" href="/consulting/">Consulting and Contracting</a></li>
#                   <li><a class="grey-text text-lighten-3" href="https://www.facebook.com/pythonprogramming.net/">Facebook</a></li>
#                   <li><a class="grey-text text-lighten-3" href="https://twitter.com/sentdex">Twitter</a></li>
#                   <li><a class="grey-text text-lighten-3" href="https://instagram.com/sentdex">Instagram</a></li>
#                 </ul>
#               </div>
#               <div class="col l4 offset-l2 s12">
#                 <h6 class="white-text">Legal stuff:</h6>
#                 <ul>
#                   <li><a class="grey-text text-lighten-3" href="/about/tos/">Terms and Conditions</a></li>
#                   <li><a class="grey-text text-lighten-3" href="/about/privacy-policy/">Privacy Policy</a></li>
#
#                 </ul>
#               </div>
#             </div>
#           </div>
#           <a href="https://xkcd.com/353/" target='blank'><p class="grey-text right" style='padding-right:10px'>Programming is a superpower.</p></a>
#           <div class="footer-copyright">
#             <div class="container">
#             © OVER 9000! PythonProgramming.net
#
#             </div>
#
#           </div>
#         </footer>
#
# </html>

# %% [markdown]
# Ejemplo 3: Errores que por ejemplo pueden dar algunas paginas a robots que no pueden identificarse.
# Por ejemplo: google.com

# %%
# used to parse values into the url
import urllib.parse


url = 'https://www.google.com/search'
values = {'q' : 'python programming tutorials'}

data = urllib.parse.urlencode(values)
data = data.encode('utf-8') # data should be bytes
req = urllib.request.Request(url, data)
resp = urllib.request.urlopen(req)
respData = resp.read()

print(respData)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       9 data = data.encode('utf-8') # data should be bytes
#      10 req = urllib.request.Request(url, data)
# ---> 11 resp = urllib.request.urlopen(req)
#      12 respData = resp.read()
#      14 print(respData)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.12/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.12/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /opt/homebrew/Cellar/python@3.11/3.11.12/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /opt/homebrew/Cellar/python@3.11/3.11.12/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.12/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /opt/homebrew/Cellar/python@3.11/3.11.12/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 405: Method Not Allowed

# %% [markdown]
# Ejemplo 4: traer información de google.com

# %%
try:
    url = 'https://www.google.com/search?q=OpenAI'

    # now, with the below headers, we defined ourselves as a simpleton who is
    # still using internet explorer.
    headers = {}
    headers['User-Agent'] = "Mozilla/5.0 (X11; Linux i686) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1312.27 Safari/537.17"
    req = urllib.request.Request(url, headers = headers)
    resp = urllib.request.urlopen(req)
    respData = resp.read()

    saveFile = open('withHeaders.txt','w')
    saveFile.write(str(respData))
    saveFile.close()
except Exception as e:
    print(str(e))

# %%
import time
import urllib.error

def fetch_google_data(query):
    encoded_query = urllib.parse.quote(query)
    url = f"https://www.google.com/search?q={encoded_query}"
    headers = {}
    headers['User-Agent'] = "Mozilla/5.0 (X11; Linux i686) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1312.27 Safari/537.17"

    try:
        req = urllib.request.Request(url, headers = headers)
        response = urllib.request.urlopen(req)
        html_content = response.read()
        print(html_content)
    except urllib.error.HTTPError as e:
        if e.code == 429:  # Too Many Requests
            print("Too many requests. Retrying in 10 seconds...")
            time.sleep(10)
            fetch_google_data(query)
        else:
            print("An error occurred:", e)

# Example usage
query = "OpenAI"
fetch_google_data(query)
# Out:
# b'<!DOCTYPE html><html lang="es-419"><head><title>Google Search</title><style>body{background-color:#fff}</style><script nonce="Vk8PoxXpPijBsx2YtOjNlQ">window.google = window.google || {};window.google.c = window.google.c || {ezx:false,cap:0};</script></head><body><noscript><style>table,div,span,p{display:none}</style><meta content="0;url=/httpservice/retry/enablejs?sei=cLLQaNOnOf6K7NYPrZK1uQQ" http-equiv="refresh"><div style="display:block">Haz clic <a href="/httpservice/retry/enablejs?sei=cLLQaNOnOf6K7NYPrZK1uQQ">aqu\xc3\xad</a> si no vuelves a acceder en pocos segundos.</div></noscript><script nonce="Vk8PoxXpPijBsx2YtOjNlQ">(function(){var sctm=false;(function(){sctm&&google.tick("load","pbsst");}).call(this);})();</script><script nonce="Vk8PoxXpPijBsx2YtOjNlQ">//# sourceMappingURL=data:application/json;charset=utf-8;base64,eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cmNlc0NvbnRlbnQiOlsiICJdLCJuYW1lcyI6WyJjbG9zdXJlRHluYW1pY0J1dHRvbiJdLCJtYXBwaW5ncyI6IkFBQUE7QUFBQTtBQUFBO0FBQUE7QUFBQTtBQUFBO0FBQUEifQ==\n(function(){var M=function(V,t,p,z,U,I,S,n,x,C){for(x=t;x!=86;)if(x==35){if((S=(n=z,B.trustedTypes))&&S.createPolicy){try{n=S.createPolicy(U,{createHTML:F,createScript:F,createScriptURL:F})}catch(e){if(B.console)B.console[I](e.message)}C=n}else C=n;x=66}else if(x==V)x=(p>>2&7)>=4&&p-3>>4<4?5:25;else if(x==5)C=z,x=25;else if(x==t)x=V;else{if(x==66)return C;x==25&&(x=(p^22)>=11&&p-V>>5<1?35:66)}},F=function(V){return M.call(this,8,62,16,V)},B=this||self;(0,eval)(function(V,t){return(t=M(8,62,3,null,"ks","error"))&&V.eval(t.createScript("1"))===1?function(p){return t.createScript(p)}:function(p){return""+p}}(B)(Array(Math.random()*7824|0).join("\\n")+[\'//# sourceMappingURL=data:application/json;charset=utf-8;base64,eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cmNlc0NvbnRlbnQiOlsiICJdLCJuYW1lcyI6WyJjbG9zdXJlRHluYW1pY0J1dHRvbiJdLCJtYXBwaW5ncyI6IkFBQUE7QUFBQTtBQUFBO0FBQUE7QUFBQTtBQUFBO0FBQUEifQ==\',\n\'(function(){/*\',\n\'\',\n\' Copyright Google LLC\',\n\' SPDX-License-Identifier: Apache-2.0\',\n\'*/\',\n\'var v7=function(p,V,x,t,n,B,F,S,M){for(S=18;S!=12;)if(S==16)B=void 0,S=53;else if(S==66)S=F?4:16;else{if(S==48)return M;S==36?(B=F(n).replace(/\\\\+/g,"-").replace(/\\\\//g,"_").replace(/=/g,""),S=53):S==72?(t+=8192,S=76):S==18?S=40:S==p?(F=window.btoa,S=66):S==76?S=t<x.length?86:36:S==4?(n="",t=0,S=62):S==62?S=76:S==40?S=(V&19)==V?26:37:S==37?S=(V&109)==V?p:48:S==86?(n+=String.fromCharCode.apply(null,x.slice(t,t+8192)),S=72):S==26?(t.S=((t.S?t.S+"~":"E:")+n.message+":"+n.stack).slice(x,2048),S=37):S==53&&(M=B,S=48)}},U_=function(p,V,x,t,n,B,F,S,M,I,z){{z=70;while(z!=72){if(z==p)throw Error("Invalid class name "+t);if(z==90)z=13;else if(z==60)F=D(34,x,0,n,t),(B=F>=0)&&Array.prototype.splice.call(n,F,x),I=B,z=46;else if(z==93)z=(V-6^20)<V&&V-2<<1>=V?35:34;else{if(z==55)throw Error("Invalid decorator function "+x);if(z==6)S in M&&n.call(void 0,M[S],S,B),z=14;else if(z==35)F=B.length,M=typeof B==="string"?B.split(x):B,S=t,z=90;else if(z==13)z=S<F?6:34;else if(z==50)z=typeof x!=="function"?55:73;else if(z==56)z=(V|72)==V?60:46;else if(z==74)z=t?50:p;else if(z==46)z=(V+3&42)>=V&&(V-8^16)<V?1:93;else{if(z==73)return I;z==70?z=56:z==34?z=(V-4&3)==1?74:73:z==1?(this.Nr=q.document||document,z=93):z==14&&(S++,z=13)}}}}},nE=function(p,V,x,t,n,B,F,S,M,I,z){(x>>1&16)<10&&(x|7)>=-69&&(t=tb(true,8,V),-~(t&128)+(t&-129)+(~t|128)&&(t=-(t|127)-p*~(t|127)+(t^127)+p*(~t^127)|tb(true,8,V)<<7),z=t);while((x&123)==x){for(B=(F=r(V,46),p);t>p;t--)B=(n=B<<8,S=tb(true,8,V),-(n&S)-2*~(n&S)+-2+(n^S));if(Z(V,F,B),9)break}(x+3^23)>=x&&(x+1&25)<x&&(z=(S=(M=(F=V[t]<<24,n=V[(t|0)+1]<<p,-~(F|n)+(F^n)+(~F^n)),I=V[(t|0)+2]<<8,2*(M|0)-2*(M&I)-~I+(~M|I)),B=V[8+3*(t&-4)+(~t^3)+(~t|3)],2*(S&B)+~(S&B)-(~S^B)));while(false==![]){return z;if("u")break}},D=function(p,V,x,t,n,B,F,S){for(F=62;F!=86;)if(F==77)S=D(35,V,0,t,x)>=0,F=66;else if(F==49)S=Math.floor(this.K()),F=7;else if(F==5)F=(p-6^8)>=p&&(p-4^31)<p?75:35;else{if(F==7)return S;if(F==8)F=(p>>1&15)==1?1:25;else if(F ...

# %% [markdown]
# # Leer archivos usando Pandas

# %% [markdown]
# Ejemplo 5: Uso de Pandas para Leer archivos
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#io-read-csv-table

# %% [markdown]
# Ejemplo 6: Trabajando con CSV files
#
# 1. Conectarse a google drive

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#%cd '/content/drive/MyDrive/CursoNLP/sesion1/datasets'
#%ls

# %% [markdown]
# Leer el archivo csv diabetes de google drive

# %%
import pandas as pd

df = pd.read_csv('../data/diabetes.csv')
df
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df.columns = [f"dia_{col}" for col in df.columns]
df
# Out:
#      dia_preg  dia_plas  dia_pres  dia_skin  dia_insu  dia_mass  dia_pedi  \
# 0           6       148        72        35         0      33.6     0.627
# 1           1        85        66        29         0      26.6     0.351
# 2           8       183        64         0         0      23.3     0.672
# 3           1        89        66        23        94      28.1     0.167
# 4           0       137        40        35       168      43.1     2.288
# ..        ...       ...       ...       ...       ...       ...       ...
# 763        10       101        76        48       180      32.9     0.171
# 764         2       122        70        27         0      36.8     0.340
# 765         5       121        72        23       112      26.2     0.245
# 766         1       126        60         0         0      30.1     0.349
# 767         1        93        70        31         0      30.4     0.315
#
#      dia_age        dia_class
# 0         50  tested_positive
# 1         31  tested_negative
# 2         32  tested_positive
# 3         21  tested_negative
# 4         33  tested_positive
# ..       ...              ...
# 763       63  tested_negative
# 764       27  tested_negative
# 765       30  tested_negative
# 766       47  tested_positive
# 767       23  tested_negative
#
# [768 rows x 9 columns]

# %%
df = df.drop('dia_plas', axis=1)
df
# Out:
#      dia_preg  dia_pres  dia_skin  dia_insu  dia_mass  dia_pedi  dia_age  \
# 0           6        72        35         0      33.6     0.627       50
# 1           1        66        29         0      26.6     0.351       31
# 2           8        64         0         0      23.3     0.672       32
# 3           1        66        23        94      28.1     0.167       21
# 4           0        40        35       168      43.1     2.288       33
# ..        ...       ...       ...       ...       ...       ...      ...
# 763        10        76        48       180      32.9     0.171       63
# 764         2        70        27         0      36.8     0.340       27
# 765         5        72        23       112      26.2     0.245       30
# 766         1        60         0         0      30.1     0.349       47
# 767         1        70        31         0      30.4     0.315       23
#
#            dia_class
# 0    tested_positive
# 1    tested_negative
# 2    tested_positive
# 3    tested_negative
# 4    tested_positive
# ..               ...
# 763  tested_negative
# 764  tested_negative
# 765  tested_negative
# 766  tested_positive
# 767  tested_negative
#
# [768 rows x 8 columns]

# %% [markdown]
# # Lectura de Diferentes Tipos de Archivos

# %% [markdown]
# 2. Recopilación de datos de archivos PDF

# %%
import PyPDF2

# PDF file to be read
pdf_file = "../data/chapter1.pdf"

# Open the PDF file
with open(pdf_file, "rb") as file:
    # Create a PDF object
    pdf = PyPDF2.PdfReader(file)
    
    # Get the number of pages in the PDF
    num_pages = len(pdf.pages)
    
    # Iterate through each page
    for page_num in range(num_pages):
        # Get the page object
        page = pdf.pages[page_num]
        
        # Extract the text from the page
        text = page.extract_text()
        
        # Print the text
        print(text)
# Out:
# CHAPTER I"Well, Prince, so Genoa and Lucca are now just family estates of theBuonapartes. But I warn you, if you don't tell me that this means war,if you still try to defend the infamies and horrors perpetrated bythat Antichrist- I really believe he is Antichrist- I will havenothing more to do with you and you are no longer my friend, no longermy 'faithful slave,' as you call yourself! But how do you do? I seeI have frightened you- sit down and tell me all the news."It was in July, 1805, and the speaker was the well-known AnnaPavlovna Scherer, maid of honor and favorite of the Empress MaryaFedorovna. With these words she greeted Prince Vasili Kuragin, a manof high rank and importance, who was the first to arrive at herreception. Anna Pavlovna had had a cough for some days. She was, asshe said, suffering from la grippe; grippe being then a new word inSt. Petersburg, used only by the elite.All her invitations without exception, written in French, anddelivered by a scarlet-liveried footman that morning, ran as follows:"If you have nothing better to do, Count [or Prince], and if theprospect of spending an evening with a poor invalid is not tooterrible, I shall be very charmed to see you tonight between 7 and 10-Annette Scherer.""Heavens! what a virulent attack!" replied the prince, not in theleast disconcerted by this reception. He had just entered, wearingan embroidered court uniform, knee breeches, and shoes, and hadstars on his breast and a serene expression on his flat face. He spokein that refined French in which our grandfathers not only spoke butthought, and with the gentle, patronizing intonation natural to aman of importance who had grown old in society and at court. He wentup to Anna Pavlovna, kissed her hand, presenting to her his bald,scented, and shining head, and
# "That's whatwe fathers have to put up with.... Is this princess of yours rich?""Her father is very rich and stingy. He lives in the country. Heis the well-known Prince Bolkonski who had to retire from the armyunder the late Emperor, and was nicknamed 'the King of Prussia.' He isvery clever but eccentric, and a bore. The poor girl is veryunhappy. She has a brother; I think you know him, he married LiseMeinen lately. He is an aide-de-camp of Kutuzov's and will be heretonight.""Listen, dear Annette," said the prince, suddenly taking AnnaPavlovna's hand and for some reason drawing it downwards. "Arrangethat affair for me and I shall always be your most devoted slave-slafe wigh an f, as a village elder of mine writes in his reports. Sheis rich and of good family and that's all I want."And with the familiarity and easy grace peculiar to him, he raisedthe maid of honor's hand to his lips, kissed it, and swung it to andfro as he lay back in his armchair, looking in another direction."Attendez," said Anna Pavlovna, reflecting, "I'll speak to Lise,young Bolkonski's wife, this very evening, and perhaps the thing canbe arranged. It shall be on your family's behalf that I'll start myapprenticeship as old maid."

# %% [markdown]
# 3. Import HTML files

# %%
import pandas as pd
pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list",match="Almena State Bank")
# Out:
# [                                            Bank Name                City  \
#  0                        The Santa Anna National Bank          Santa Anna
#  1                                Pulaski Savings Bank             Chicago
#  2                  The First National Bank of Lindsay             Lindsay
#  3               Republic First Bank dba Republic Bank        Philadelphia
#  4                                       Citizens Bank            Sac City
#  5                            Heartland Tri-State Bank             Elkhart
#  6                                 First Republic Bank       San Francisco
#  7                                      Signature Bank            New York
#  8                                 Silicon Valley Bank         Santa Clara
#  9                                   Almena State Bank              Almena
#  10                         First City Bank of Florida   Fort Walton Beach
#  11                               The First State Bank       Barboursville
#  12                                 Ericson State Bank             Ericson
#  13                   City National Bank of New Jersey              Newark
#  14                                      Resolute Bank              Maumee
#  15                              Louisa Community Bank              Louisa
#  16                               The Enloe State Bank              Cooper
#  17                Washington Federal Bank for Savings             Chicago
#  18    The Farmers and Merchants State Bank of Argonia             Argonia
#  19                                Fayette County Bank          Saint Elmo
#  20  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
#  21                                     First NBC Bank         New Orleans
#  22                                      Proficio Bank  Cottonwood Heights
#  23                      Seaway Bank and Trust Company             Chicago
#  24                             Harvest Community Bank          Pennsville
#
#              State   Cert                Acquiring Institution  \
#  0           Texas   5520            Coleman County State Bank
#  1        Illinois  28611                      Millennium Bank
#  2        Oklahoma   4134               First Bank & Trust Co.
#  3    Pennsylvania  27332    Fulton Bank, National Association
#  4            Iowa   8758            Iowa Trust & Savings Bank
#  5          Kansas  25851               Dream First Bank, N.A.
#  6      California  59017            JPMorgan Chase Bank, N.A.
#  7        New York  57053                  Flagstar Bank, N.A.
#  8      California  24735  First Citizens Bank & Trust Company
#  9          Kansas  15426                          Equity Bank
#  10        Florida  16748            United Fidelity Bank, fsb
#  11  West Virginia  14361                       MVB Bank, Inc.
#  12       Nebraska  18265           Farmers and Merchants Bank
#  13     New Jersey  21111                      Industrial Bank
#  14           Ohio  58317                   Buckeye State Bank
#  15       Kentucky  58112    Kentucky Farmers Bank Corporation
#  16          Texas  10716                   Legend Bank, N. A.
#  17       Illinois  30570                   Royal Savings Bank
#  18         Kansas  17719                          Conway Bank
#  19       Illinois   1802            United Fidelity Bank, fsb
#  20      Wisconsin  30003  First-Citizens Bank & Trust Company
#  21      Louisiana  58302                         Whitney Bank
#  22           Utah  35495                    Cache Valley Bank
#  23       Illinois  19328                  State Bank of Texas
#  24     New Jersey  34951  First-Citizens Bank & Trust Company
#
#           Closing Date  Fund  Sort ascending
#  0       June 27, 2025                 10549
#  1    January 17, 2025                 10548
#  2    October 18, 2024                 10547
#  3      April 26, 2024                 10546
#  4    November 3, 2023                 10545
#  5       July 28, 2023                 10544
#  6         May 1, 2023                 10543
#  7      March 12, 2023                 10540
#  8      March 10, 2023                 10539
#  9    October 23, 2020                 10538
#  10   October 16, 2020                 10537
#  11      April 3, 2020                 10536
#  12  February 14, 2020                 10535
#  13   November 1, 2019                 10534
#  14   October 25, 2019                 10533
#  15   October 25, 2019                 10532
#  16       May 31, 2019                 10531
#  17  December 15, 2017                 10530
#  18   October 13, 2017                 10529
#  19       May 26, 2017                 10528
#  20        May 5, 2017                 10527
#  21     April 28, 2017                 10526
#  22      March 3, 2017                 10525
#  23   January 27, 2017                 10524
#  24   January 13, 2017                 10523  ]

# %% [markdown]
# 4. Importando de Word Documents

# %%
import docx

# Word document file to be read
docx_file = "../data/Startup-Peru-9G.docx"

# Open the Word document
doc = docx.Document(docx_file)

# Extract the text from the document
text = []
for para in doc.paragraphs:
    text.append(para.text)

# Print the text
print("\n".join(text))
# Out:
# Formato I: Formato de postulación
#
# Advertencia: Este formato es referencial, los solicitantes deberán desarrollar la ficha de solicitud en el Sistema en Línea (https://inngenius.proinnovate.gob.pe/. No se recibirán propuestas en forma física.
#
#  A.1.   DATOS BÁSICOS
#
# A.2.   VIDEO EXPLICATIVO
#
# B.1.  MÉRITO INNOVADOR
#
# B.2.   MODELO DE NEGOCIO
#
# B.3.   ESCALABILIDAD
#
#  B.4. EQUIPO EMPRENDEDOR
#
# B.5.   SOSTENIBILIDAD AMBIENTAL Y/O ADAPTACIÓN O MITIGACIÓN AL CAMBIO CLIMÁTICO
#
#
# C.1. FINANCIAMIENTO
# C.1.1. El presupuesto debe cumplir con los porcentajes máximos y mínimos de aporte según lo establecido en las presentes bases.
#
# D.1. DOCUMENTOS
# Debe cumplir con adjuntar cada uno de los documentos completos.
#
#
# Formato II: Declaración jurada de chequeo legal y compromiso
#
# Nota: En caso postulen como personas naturales, firman todos los miembros del equipo emprendedor. En caso postulen como empresa joven, adicionalmente firma el representante legal de la empresa en caso fuese una persona distinta.
#
# Los miembros del Equipo Emprendedor declaramos bajo juramento que:
#
# Sobre el equipo emprendedor y la propuesta:
#
# Todos somos miembros fundadores de la startup.
# Por lo menos 1 persona del equipo emprendedor se dedicará al 100% al proyecto (40 horas a la semana).
# La propuesta es original y no copiada o plagiada de otra.
# La propuesta presentada no viola ningún derecho de propiedad intelectual.
# La propuesta no está relacionada con la promoción de uso de armas, juegos de azar, actividades ilegales, prohibidas o de ética dudosa.
# La información descrita en el formulario es veraz
# Cumplimos con las bases del concurso.
#
# Sobre los requisitos legales de los miembros del equipo emprendedor:
#
# Somos mayores de edad, contamos con DNI o carnet de extranjería vigente (residentes) o, de ser extranjeros, con pasaporte vigente al momento de postular al Concurso.
# No contamos con antecedentes penales ni policiales.
# No tenemos deudas tributarias.
# No estamos sancionados con inhabilitación temporal o definitiva para contratar con el Estado peruano, mientras dure tal sanción.
# No hemos sido condenados mediante sentencia consentida o ejecutoriada por delitos cometidos en agravio del Estado peruano.
# No estamos relacionados con las personas con vínculo laboral de ProInnóvate hasta el cuarto grado de consanguinidad y segundo de afinidad, por razón de matrimonio, unión de hecho o convivencia.
# No ejerceremos una función pública en las Entidades del Estado al momento de la suscripción del contrato.
# No nos encontramos en el Registro de Deudores Alimentarios Morosos del Poder Judicial (REDAM).
# No estamos observados por ProInnóvate u otra fuente de financiamiento a la que ProInnóvate tenga acceso.
#
# Sobre los requisitos legales de la empresa (en caso aplique):
#
# Estar legalmente constituidas en el Perú y contar con RUC activo y habido.
# Contar como máximo con cinco (05) años de operación en el Registro Único de Contribuyentes (RUC) de SUNAT a la fecha de cierre de la convocatoria.
# No estar sancionado con inhabilitación temporal o definitiva para contratar con el Estado Peruano, mientras dure tal sanción
# No presentar deudas coactivas reportadas de seguridad social de los trabajadores ni de otras obligaciones tributarias o no tributarias.
# No estar sometido a ningún procedimiento previsto en la Ley General del Sistema Concursal, ni en cualquier norma que la sustituya, modifique o complemente.
# No encontrarse calificado con una calificación menor a “Cliente con Problemas Potenciales” en la central de riesgo de la SBS.
# No tener deudas coactivas con la SUNAT.
# No estar observada por ProInnóvate u otra fuente de financiamiento a la que ProInnóvate tenga acceso.
#
# Sobre los compromisos asumidos:
#
# Cumpliremos con prácticas empresariales responsables y éticas para el desarrollo de la propuesta.
# Brindaremos mentorías y participaremos como ponentes en eventos de Startup Perú.
# Proporcionaremos la información necesaria para fines de difusión y medición de Startup Perú de manera semestral vía encuestas.
# Es de nuestro conocimiento que se mantendrá en reserva la identidad de los evaluadores externos y miembros del comité de evaluación de ProInnóvate para garantizar un proceso idóneo.
# Respetaremos los resultados de los procesos de evaluación, los que no son susceptibles de ser impugnados en ninguna etapa del proceso.
#
#
#
# Formato III: Modelo de Pagaré a la vista
#
# Nota: Este formato es referencial.
#
# MONTO: S/______________ (colocar el costo del programa) VENCIMIENTO: A la vista
# CÓDIGO DE PROYECTO:
#
#  Yo, ______________(colocar nombre completo del líder emprendedor si postula como persona natural o nombre del Representante legal si postula como persona jurídica), en mi calidad de (colocar según corresponda)
# Líder emprendedor y coordinador general del proyecto (en adelante, CGP)
# Representante legal de la empresa ____________ (nombre de empresa)
# De conformidad con lo establecido en el Artículo 52 de la Ley 27287, queda establecido que el presente Pagaré no requiere ser protestado; sin embargo, el tenedor queda facultado a protestarlo por falta de pago, en cuyo caso asumiré los gastos y comisiones de tal diligencia notarial o de la formalidad sustitutoria correspondiente. Esta diligencia del protesto podrá ser hecho mediante notificación que se curse al domicilio del Emitente consignado en este Pagaré; salvo que se opte por la formalidad sustitutoria de ley.
#
# Me someto a la competencia de los Jueces y Tribunales del Distrito Judicial de Lima para todos los actos, efectos y consecuencias que se deriven de la emisión, interpretación, pago, ejecución y cobranza de la cantidad representada por el presente Pagaré, así como de los intereses, comisiones y gastos que se originen con relación a aquel.
#
# Señalo como mi domicilio para cualquier notificación, comunicación o requerimiento que deba efectuarse en relación al presente Pagaré sea de carácter judicial o extrajudicial y de igual forma autorizo expresamente que las comunicaciones sean remitidas válidamente a la dirección electrónica _______________ (Correo electrónico del CGP o representante legal, según corresponda) o al domicilio ubicado en _______________ (Dirección del CGP o representante legal, según corresponda); lugar donde se me efectuarán válidamente las notificaciones para todos los efectos del presente Pagaré.
#
# El presente Pagaré se encuentra regulado y deberá ser interpretado conforme a las disposiciones legales aplicables que se encuentran vigentes en la República del Perú. En particular, sin que la presente enumeración tenga carácter limitativo, serán aplicables al presente pagaré las disposiciones contenidas en la Ley de Títulos Valores - Ley N° 27287 y sus modificatorias, el Código Civil y el Código Procesal Civil, así como las disposiciones legales que las sustituyan en el futuro, salvo aquellas disposiciones de carácter supletorio que fuesen inconsistentes con el texto expreso del mismo.
#
# Declaro tener capacidad y estar plenamente facultado para suscribir y emitir el presente Pagaré.
#
# Lima, [día] de [mes] de [año]
#
# Firma:  ______________________________			Huella Digital _________
#
# (Nombres y Apellidos)
# Líder Emprendedor/Representante Legal según corresponda
# D.N.I. N° _____________

# %% [markdown]
# 5. Leer archivos json

# %%
import json

# JSON file to be read
json_file = "../data/chapter1.json"

# Open the JSON file
with open(json_file) as file:
    # Load the JSON data
    data = json.load(file)
    
    # Print the data
    print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 7
#       4 json_file = "chapter1.json"
#       6 # Open the JSON file
# ----> 7 with open(json_file) as file:
#       8     # Load the JSON data
#       9     data = json.load(file)
#      11     # Print the data
#
# File ~/Projects/news-webscrapping/env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chapter1.json'

# %%
# !pip3 install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\usuario\anaconda3\envs\nlp310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\usuario\anaconda3\envs\nlp310\lib\site-packages)

# %%
import pandas as pd

# Provide the path to your Excel file
excel_file_path = 'renuncias.xlsx'

# Read the Excel file into a DataFrame
df = pd.read_excel(excel_file_path)

# Assuming you have a column named 'text' in the Excel file, you can access it like this:
#text_column = df['CARGO_ACTUAL','TIPO_CONTRATO']

# Now, 'text_column' contains the text data from the 'text' column of your Excel file.

# You can also loop through the rows to access the text in each row if needed:
for index, row in df.iterrows():
    text_a = row['CARGO_ACTUAL']
    text_b = row['TIPO_CONTRATO']
    print(f"Row {index + 1}: Text A: {text_a}, Text B: {text_b}")
# Out:
# Row 1: Text A: JEFE DE PROYECTOS , Text B: INDEFINIDO
# Row 2: Text A: ANALISTA FUNCIONAL, Text B: INDEFINIDO
# Row 3: Text A: ANALISTA FUNCIONAL, Text B: INDEFINIDO
# Row 4: Text A: JEFE DE PROYECTOS , Text B: INDEFINIDO
# Row 5: Text A: ANALISTA FUNCIONAL, Text B: INDEFINIDO
# Row 6: Text A: ANALISTA DE SISTEMAS, Text B: INDEFINIDO
# Row 7: Text A: ANALISTA DE SISTEMAS, Text B: INDEFINIDO
# Row 8: Text A: ANALISTA FUNCIONAL, Text B: INDEFINIDO
# Row 9: Text A: JEFE DE PROYECTOS , Text B: INDEFINIDO
# Row
Text A: JEFE DE PROYECTOS , Text B: INCREMENTO DE ACTIVIDADES
# Row 896: Text A: JEFE DE PROYECTOS , Text B: INCREMENTO DE ACTIVIDADES
# Row 897: Text A: ANALISTA FUNCIONAL, Text B: INCREMENTO DE ACTIVIDADES
# Row 898: Text A: ANALISTA DE SOPORTE DE RED, Text B: INCREMENTO DE ACTIVIDADES
# Row 899: Text A: ANALISTA DE CALIDAD, Text B: INCREMENTO DE ACTIVIDADES
# Row 900: Text A: DISEÑADOR WEB, Text B: INCREMENTO DE ACTIVIDADES
# Row 901: Text A: ESPECIALISTA DE INFRAESTRUCTURA, Text B: INCREMENTO DE ACTIVIDADES
# Row 902: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 903: Text A: ANALISTA PROGRAMADOR, Text B: INCREMENTO DE ACTIVIDADES
# Row 904: Text A: OPERADOR DE SISTEMAS , Text B: INCREMENTO DE ACTIVIDADES
# Row 905: Text A: ASISTENTE DE PROYECTOS, Text B: INCREMENTO DE ACTIVIDADES
# Row 906: Text A: ANALISTA BI, Text B: INCREMENTO DE ACTIVIDADES
# Row 907: Text A: ANALISTA PROGRAMADOR, Text B: INCREMENTO DE ACTIVIDADES
# Row 908: Text A: ANALISTA PROGRAMADOR, Text B: INCREMENTO DE ACTIVIDADES
# Row 909: Text A: ANALISTA DE SOPORTE DE APLICACIONES, Text B: INCREMENTO DE ACTIVIDADES
# Row 910: Text A: ANALISTA DE SOPORTE DE APLICACIONES, Text B: INCREMENTO DE ACTIVIDADES
# Row 911: Text A: ANALISTA DE SOPORTE DE APLICACIONES, Text B: INCREMENTO DE ACTIVIDADES
# Row 912: Text A: ANALISTA PROGRAMADOR, Text B: INCREMENTO DE ACTIVIDADES
# Row 913: Text A: ADMINISTRADOR DE BASE DE DATOS, Text B: INCREMENTO DE ACTIVIDADES
# Row 914: Text A: ANALISTA BI, Text B: OBRA
# Row 915: Text A: ANALISTA BI, Text B: OBRA
# Row 916: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 917: Text A: ANALISTA BI, Text B: OBRA
# Row 918: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 919: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 920: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 921: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 922: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 923: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 924: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 925: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 926: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 927: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 928: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 929: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 930: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 931: Text A: ASISTENTE DE PROYECTOS, Text B: OBRA
# Row 932: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 933: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 934: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 935: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 936: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 937: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 938: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 939: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 940: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 941: Text A: ASISTENTE DE PROYECTOS, Text B: OBRA
# Row 942: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 943: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 944: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 945: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 946: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 947: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 948: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 949: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 950: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 951: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 952: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 953: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 954: Text A: ANALISTA BI, Text B: OBRA
# Row 955: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 956: Text A: ARQUITECTO DE SOFTWARE, Text B: OBRA
# Row 957: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 958: Text A: ANALISTA BI, Text B: OBRA
# Row 959: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 960: Text A: ASISTENTE DE PROYECTOS, Text B: OBRA
# Row 961: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 962: Text A: OPERADOR DE SISTEMAS , Text B: OBRA
# Row 963: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 964: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 965: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 966: Text A: ANALISTA BI, Text B: OBRA
# Row 967: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 968: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 969: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 970: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 971: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 972: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 973: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 974: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 975: Text A: ANALISTA DE CALIDAD, Text B: OBRA
# Row 976: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 977: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 978: Text A: ANALISTA DE SOPORTE DE APLICACIONES, Text B: OBRA
# Row 979: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 980: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 981: Text A: ANALISTA DE SOPORTE DE APLICACIONES, Text B: OBRA
# Row 982: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 983: Text A: ANALISTA PROGRAMADOR, Text B: PERSONAL EXTRANJERO
# Row 984: Text A: OPERADOR DE SISTEMAS , Text B: OBRA
# Row 985: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 986: Text A: ASISTENTE DE PROYECTOS, Text B: OBRA
# Row 987: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 988: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 989: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 990: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 991: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 992: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 993: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 994: Text A: ESPECIALISTA DESARROLLADOR, Text B: OBRA
# Row 995: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 996: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 997: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 998: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 999: Text A: OPERADOR DE SISTEMAS , Text B: OBRA
# Row 1000: Text A: OPERADOR DE SISTEMAS , Text B: OBRA
# Row 1001: Text A: ANALISTA BI, Text B: OBRA
# Row 1002: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 1003: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 1004: Text A: JEFE DE PROYECTOS , Text B: INDEFINIDO
# Row 1005: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 1006: Text A: ANALISTA FUNCIONAL, Text B: OBRA
# Row 1007: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 1008: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 1009: Text A: JEFE DE PROYECTOS , Text B: OBRA
# Row 1010: Text A: ANALISTA FUNCIONAL, Text B: PERSONAL EXTRANJERO
# Row 1011: Text A: ESPECIALISTA DESARROLLADOR, Text B: OBRA
# Row 1012: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
# Row 1013: Text A: ANALISTA PROGRAMADOR, Text B: OBRA
